# %% [markdown]
# <a href="https://colab.research.google.com/github/Ines8991/classification_rna/blob/main/Pretraitement1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
note=pd.read_excel(r'/content/Ines - Liste des étudiants avec notes par session 07-07-2023.xlsx')
note.shape
# Out:
# (118024, 6)

# %%
note.columns.tolist()
# Out:
# ["Année de l'inscription",
#  'Individu - Code Etudiant',
#  'Note Session 1',
#  'Résultat Session 1',
#  'Note Session 2',
#  'Résultat Session 2']

# %%
note2012=note[note["Année de l'inscription"]==2012]
note2013=note[note["Année de l'inscription"]==2013]
note2014=note[note["Année de l'inscription"]==2014]
note2015=note[note["Année de l'inscription"]==2015]
note2016=note[note["Année de l'inscription"]==2016]
note2017=note[note["Année de l'inscription"]==2017]
note2018=note[note["Année de l'inscription"]==2018]
note2019=note[note["Année de l'inscription"]==2019]
note2020=note[note["Année de l'inscription"]==2020]
note2021=note[note["Année de l'inscription"]==2021]
note2022=note[note["Année de l'inscription"]==2022]

# %%
sui2012=pd.read_excel(r'/content/Suivi2012.xlsx')
sui2013=pd.read_excel(r'/content/Suivi2013.xlsx')
sui2014=pd.read_excel(r'/content/Suivi2014.xlsx')
sui2015=pd.read_excel(r'/content/Suivi2015.xlsx')
sui2016=pd.read_excel(r'/content/Suivi2016.xlsx')
sui2017=pd.read_excel(r'/content/Suivi2017.xlsx')
sui2018=pd.read_excel(r'/content/Suivi2018.xlsx')
sui2019=pd.read_excel(r'/content/Suivi2019.xlsx')
sui2020=pd.read_excel(r'/content/Suivi2020.xlsx')
sui2021=pd.read_excel(r'/content/Suivi2021.xlsx')

# %%
ca2012=pd.read_excel(r'/content/ca2012.xlsx')
ca2013=pd.read_excel(r'/content/ca2013.xlsx')
ca2014=pd.read_excel(r'/content/ca2014.xlsx')
ca2015=pd.read_excel(r'/content/ca2015.xlsx')
ca2016=pd.read_excel(r'/content/ca2016.xlsx')
ca2017=pd.read_excel(r'/content/ca2017 (1).xlsx')
ca2018=pd.read_excel(r'/content/ca2018.xlsx')
ca2019=pd.read_excel(r'/content/ca2019.xlsx')
ca2020=pd.read_excel(r'/content/ca2020.xlsx')
ca2021=pd.read_excel(r'/content/ca2021.xlsx')
ca2022=pd.read_excel(r'/content/ca2022 (1).xlsx')

# %%
dist=pd.read_excel(r'/content/distance_et_nom_commune.xlsx')

# %%
ca2021['Adresse fixe - Commune (code)'].fillna(0,inplace=True)
ca2012['Adresse fixe - Commune (code)'].fillna(0,inplace=True)
ca2021['Adresse fixe - Commune (code)']=ca2021['Adresse fixe - Commune (code)'].astype(int)
ca2021['Adresse fixe - Commune (code)'] = ca2021['Adresse fixe - Commune (code)'].astype(str)
ca2021['Adresse fixe - Commune (code)'] = ca2021['Adresse fixe - Commune (code)'].apply(lambda x: f'{x}')
ca2012['Adresse fixe - Commune (code)']=ca2012['Adresse fixe - Commune (code)'].astype(int)
ca2012['Adresse fixe - Commune (code)'] = ca2012['Adresse fixe - Commune (code)'].astype(str)
ca2012['Adresse fixe - Commune (code)'] = ca2012['Adresse fixe - Commune (code)'].apply(lambda x: f'{x}')

# %%
ca2021['Adresse fixe - Commune (code)'].unique()
# Out:
# array(['1358', '92012', '93079', ..., '27507', '62013', '30243'],
#       dtype=object)

# %%
ca2012=pd.merge(ca2012,dist,on="Adresse fixe - Commune (code)",how="left")
ca2013=pd.merge(ca2013,dist,on="Adresse fixe - Commune (code)",how="left")
ca2014=pd.merge(ca2014,dist,on="Adresse fixe - Commune (code)",how="left")
ca2015=pd.merge(ca2015,dist,on="Adresse fixe - Commune (code)",how="left")
ca2016=pd.merge(ca2016,dist,on="Adresse fixe - Commune (code)",how="left")
ca2017=pd.merge(ca2017,dist,on="Adresse fixe - Commune (code)",how="left")
ca2018=pd.merge(ca2018,dist,on="Adresse fixe - Commune (code)",how="left")
ca2019=pd.merge(ca2019,dist,on="Adresse fixe - Commune (code)",how="left")
ca2020=pd.merge(ca2020,dist,on="Adresse fixe - Commune (code)",how="left")
ca2021=pd.merge(ca2021,dist,on="Adresse fixe - Commune (code)",how="left")
ca2022=pd.merge(ca2022,dist,on="Adresse fixe - Commune (code)",how="left")

# %%
for i in range(len(ca2012)):
  if (ca2012['Niveau'][i]=="bac+4") or (ca2012['Niveau'][i]=="bac+5"):
    ca2012['Cursus LMD'][i]="cursus M"
  else:
    ca2012['Cursus LMD'][i]=ca2012['Cursus LMD'][i]
for i in range(len(ca2013)):
  if (ca2013['Niveau'][i]=="bac+4") or (ca2013['Niveau'][i]=="bac+5"):
    ca2013['Cursus LMD'][i]="cursus M"
  else:
    ca2013['Cursus LMD'][i]=ca2013['Cursus LMD'][i]
for i in range(len(ca2014)):
  if (ca2014['Niveau'][i]=="bac+4") or (ca2014['Niveau'][i]=="bac+5"):
    ca2014['Cursus LMD'][i]="cursus M"
  else:
    ca2014['Cursus LMD'][i]=ca2014['Cursus LMD'][i]
for i in range(len(ca2015)):
  if (ca2015['Niveau'][i]=="bac+4") or (ca2015['Niveau'][i]=="bac+5"):
    ca2015['Cursus LMD'][i]="cursus M"
  else:
    ca2015['Cursus LMD'][i]=ca2015['Cursus LMD'][i]
for i in range(len(ca2016)):
  if (ca2016['Niveau'][i]=="bac+4") or (ca2016['Niveau'][i]=="bac+5"):
    ca2016['Cursus LMD'][i]="cursus M"
  else:
    ca2016['Cursus LMD'][i]=ca2016['Cursus LMD'][i]
for i in range(len(ca2017)):
  if (ca2017['Niveau'][i]=="bac+4") or (ca2017['Niveau'][i]=="bac+5"):
    ca2017['Cursus LMD'][i]="cursus M"
  else:
    ca2017['Cursus LMD'][i]=ca2017['Cursus LMD'][i]
for i in range(len(ca2018)):
  if (ca2018['Niveau'][i]=="bac+4") or (ca2018['Niveau'][i]=="bac+5"):
    ca2018['Cursus LMD'][i]="cursus M"
  else:
    ca2018['Cursus LMD'][i]=ca2018['Cursus LMD'][i]
for i in range(len(ca2019)):
  if (ca2019['Niveau'][i]=="bac+4") or (ca2019['Niveau'][i]=="bac+5"):
    ca2019['Cursus LMD'][i]="cursus M"
  else:
    ca2019['Cursus LMD'][i]=ca2019['Cursus LMD'][i]
for i in range(len(ca2020)):
  if (ca2020['Niveau'][i]=="bac+4") or (ca2020['Niveau'][i]=="bac+5"):
    ca2020['Cursus LMD'][i]="cursus M"
  else:
    ca2020['Cursus LMD'][i]=ca2020['Cursus LMD'][i]
for i in range(len(ca2021)):
  if (ca2021['Niveau'][i]=="bac+4") or (ca2021['Niveau'][i]=="bac+5"):
    ca2021['Cursus LMD'][i]="cursus M"
  else:
    ca2021['Cursus LMD'][i]=ca2021['Cursus LMD'][i]
for i in range(len(ca2022)):
  if (ca2022['Niveau'][i]=="bac+4") or (ca2022['Niveau'][i]=="bac+5"):
    ca2022['Cursus LMD'][i]="cursus M"
  else:
    ca2022['Cursus LMD'][i]=ca2022['Cursus LMD'][i]
# Out:
# <ipython-input-11-3d10e0a1c3eb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca2012['Cursus LMD'][i]="cursus M"
# <ipython-input-11-3d10e0a1c3eb>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca2012['Cursus LMD'][i]=ca2012['Cursus LMD'][i]
# <ipython-input-11-3d10e0a1c3eb>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ca2013['Cursus LMD'][i]=ca2013['Cursus LMD'][i]
# ...

# %%
df2012=pd.merge(sui2012,ca2012,on="Individu - Code Etudiant")
df2013=pd.merge(sui2013,ca2013,on="Individu - Code Etudiant")
df2014=pd.merge(sui2014,ca2014,on="Individu - Code Etudiant")
df2015=pd.merge(sui2015,ca2015,on="Individu - Code Etudiant")
df2016=pd.merge(sui2016,ca2016,on="Individu - Code Etudiant")
df2017=pd.merge(sui2017,ca2017,on="Individu - Code Etudiant")
df2018=pd.merge(sui2018,ca2018,on="Individu - Code Etudiant")
df2019=pd.merge(sui2019,ca2019,on="Individu - Code Etudiant")
df2020=pd.merge(sui2020,ca2020,on="Individu - Code Etudiant")
df2021=pd.merge(sui2021,ca2021,on="Individu - Code Etudiant")

# %% [markdown]
# Etant donné que les doctorants font plus de 2 ans dans une filière, ils avaient été recensés comme RNA. Nous allons donc corriger cela

# %%
for i in range(len(df2012)):
  if df2012['Niveau'][i]=="bac+8":
    df2012['RNA_2013'][i]="NonRNA"

for i in range(len(df2013)):
  if df2013['Niveau'][i]=="bac+8":
    df2013['RNA_2014'][i]="NonRNA"

for i in range(len(df2014)):
  if df2014['Niveau'][i]=="bac+8":
    df2014['RNA_2015'][i]="NonRNA"

for i in range(len(df2015)):
  if df2015['Niveau'][i]=="bac+8":
    df2015['RNA_2016'][i]="NonRNA"

for i in range(len(df2016)):
  if df2016['Niveau'][i]=="bac+8":
    df2016['RNA_2017'][i]="NonRNA"

for i in range(len(df2017)):
  if df2017['Niveau'][i]=="bac+8":
    df2017['RNA_2018'][i]="NonRNA"

for i in range(len(df2018)):
  if df2018['Niveau'][i]=="bac+8":
    df2018['RNA_2019'][i]="NonRNA"

for i in range(len(df2019)):
  if df2019['Niveau'][i]=="bac+8":
    df2019['RNA_2020'][i]="NonRNA"

for i in range(len(df2020)):
  if df2020['Niveau'][i]=="bac+8":
    df2020['RNA_2021'][i]="NonRNA"

for i in range(len(df2021)):
  if df2021['Niveau'][i]=="bac+8":
    df2021['RNA_2022'][i]="NonRNA"
# Out:
# <ipython-input-13-5768530892bc>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2012['RNA_2013'][i]="NonRNA"
# <ipython-input-13-5768530892bc>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2013['RNA_2014'][i]="NonRNA"
# <ipython-input-13-5768530892bc>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2014['RNA_2015'][i]="NonRNA"
# <ipython-input-13-5768530892bc>:15: SettingWithCopyWarning:
# ...

# %%
df2012['RNA_2013'].fillna("NonRNA",inplace=True)
df2013['RNA_2014'].fillna("NonRNA",inplace=True)
df2014['RNA_2015'].fillna("NonRNA",inplace=True)
df2015['RNA_2016'].fillna("NonRNA",inplace=True)
df2016['RNA_2017'].fillna("NonRNA",inplace=True)
df2017['RNA_2018'].fillna("NonRNA",inplace=True)
df2018['RNA_2019'].fillna("NonRNA",inplace=True)
df2019['RNA_2020'].fillna("NonRNA",inplace=True)
df2020['RNA_2021'].fillna("NonRNA",inplace=True)
df2021['RNA_2022'].fillna("NonRNA",inplace=True)

# %%
data2012=pd.merge(df2012,note2012,on="Individu - Code Etudiant")
data2013=pd.merge(df2013,note2013,on="Individu - Code Etudiant")
data2014=pd.merge(df2014,note2014,on="Individu - Code Etudiant")
data2015=pd.merge(df2015,note2015,on="Individu - Code Etudiant")
data2016=pd.merge(df2016,note2016,on="Individu - Code Etudiant")
data2017=pd.merge(df2017,note2017,on="Individu - Code Etudiant")
data2018=pd.merge(df2018,note2018,on="Individu - Code Etudiant")
data2019=pd.merge(df2019,note2019,on="Individu - Code Etudiant")
data2020=pd.merge(df2020,note2020,on="Individu - Code Etudiant")
data2021=pd.merge(df2021,note2021,on="Individu - Code Etudiant")

# %%
del data2012['Année de l\'inscription_y']
del data2013['Année de l\'inscription_y']
del data2014['Année de l\'inscription_y']
del data2015['Année de l\'inscription_y']
del data2016['Année de l\'inscription_y']
del data2017['Année de l\'inscription_y']
del data2018['Année de l\'inscription_y']
del data2019['Année de l\'inscription_y']
del data2020['Année de l\'inscription_y']
del data2021['Année de l\'inscription_y']
del data2012['Unnamed: 0']
del data2013['Unnamed: 0']
del data2014['Unnamed: 0']
del data2015['Unnamed: 0']
del data2016['Unnamed: 0']
del data2017['Unnamed: 0']
del data2018['Unnamed: 0']
del data2019['Unnamed: 0']
del data2020['Unnamed: 0']
del data2021['Unnamed: 0']

# %%
data2012=data2012.add_suffix('_Année_N')
data2013=data2013.add_suffix('_Année_N')
data2014=data2014.add_suffix('_Année_N')
data2015=data2015.add_suffix('_Année_N')
data2016=data2016.add_suffix('_Année_N')
data2017=data2017.add_suffix('_Année_N')
data2018=data2018.add_suffix('_Année_N')
data2019=data2019.add_suffix('_Année_N')
data2020=data2020.add_suffix('_Année_N')
data2021=data2021.add_suffix('_Année_N')

# %%
data2012=data2012.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2013=data2013.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2014=data2014.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2015=data2015.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2016=data2016.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2017=data2017.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2018=data2018.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2019=data2019.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2020=data2020.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})
data2021=data2021.rename(columns={'Individu - Code Etudiant_Année_N':'Individu - Code Etudiant'})

# %%
data2012=data2012.rename(columns={'RNA_2013_Année_N':'RNA'})
data2013=data2013.rename(columns={'RNA_2014_Année_N':'RNA'})
data2014=data2014.rename(columns={'RNA_2015_Année_N':'RNA'})
data2015=data2015.rename(columns={'RNA_2016_Année_N':'RNA'})
data2016=data2016.rename(columns={'RNA_2017_Année_N':'RNA'})
data2017=data2017.rename(columns={'RNA_2018_Année_N':'RNA'})
data2018=data2018.rename(columns={'RNA_2019_Année_N':'RNA'})
data2019=data2019.rename(columns={'RNA_2020_Année_N':'RNA'})
data2020=data2020.rename(columns={'RNA_2021_Année_N':'RNA'})
data2021=data2021.rename(columns={'RNA_2022_Année_N':'RNA'})

# %%
data2013.columns.tolist()
# Out:
# ['Individu - Code Etudiant',
#  'RNA',
#  "Année de l'inscription_x_Année_N",
#  'Niveau_Année_N',
#  "Type d'étape_Année_N",
#  'Diplôme SISE intitulé 1 (lib.)_Année_N',
#  'IAE - Etape (lib.)_Année_N',
#  'Individu - Sexe_Année_N',
#  'Nationalité (code)_Année_N',
#  'Nationalité (lib.)_Année_N',
#  'Nationalité - continent_Année_N',
#  'Age au bac_Année_N',
#  'Bac ou équivalence (code)_Année_N',
#  'Groupe de bac_Année_N',
#  'Série du bac_Année_N',
#  'Spécialité 1 du bac NBGE_Année_N',
#  'Bac - Mention (lib.)_Année_N',
#  'Situation année précédente (lib.)_Année_N',
#  'Diplôme SISE (type)_Année_N',
#  'Discipline SISE (code)_Année_N',
#  'Discipline SISE (lib.)_Année_N',
#  'Secteur disciplinaire SISE (code)_Année_N',
#  'Secteur disciplinaire SISE (lib.)_Année_N',
#  'Niveau dans le diplôme (calc)_Année_N',
#  'PCS - parent (code)_Année_N',
#  'PCS - parent (lib.)_Année_N',
#  "Régime d'inscription (code)_Année_N",
#  "Régime d'inscription (lib.)_Année_N",
# ...

# %%
ca2012=ca2012.add_suffix('_Année_N+1')
ca2013=ca2013.add_suffix('_Année_N+1')
ca2014=ca2014.add_suffix('_Année_N+1')
ca2015=ca2015.add_suffix('_Année_N+1')
ca2016=ca2016.add_suffix('_Année_N+1')
ca2017=ca2017.add_suffix('_Année_N+1')
ca2018=ca2018.add_suffix('_Année_N+1')
ca2019=ca2019.add_suffix('_Année_N+1')
ca2020=ca2020.add_suffix('_Année_N+1')
ca2021=ca2022.add_suffix('_Année_N+1')
ca2022=ca2022.add_suffix('_Année_N+1')

# %%
del ca2012['Unnamed: 0_Année_N+1']
del ca2013['Unnamed: 0_Année_N+1']
del ca2014['Unnamed: 0_Année_N+1']
del ca2018['Unnamed: 0_Année_N+1']
del ca2015['Unnamed: 0_Année_N+1']
del ca2016['Unnamed: 0_Année_N+1']
del ca2017['Unnamed: 0_Année_N+1']
del ca2019['Unnamed: 0_Année_N+1']
del ca2020['Unnamed: 0_Année_N+1']
del ca2021['Unnamed: 0_Année_N+1']
del ca2022['Unnamed: 0_Année_N+1']

# %%
ca2012=ca2012.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2013=ca2013.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2014=ca2014.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2015=ca2015.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2016=ca2016.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2017=ca2017.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2018=ca2018.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2019=ca2019.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2020=ca2020.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2021=ca2021.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})
ca2022=ca2022.rename(columns={'Individu - Code Etudiant_Année_N+1':'Individu - Code Etudiant'})

# %%
del ca2012['Année de l\'inscription_Année_N+1']
del ca2013['Année de l\'inscription_Année_N+1']
del ca2014['Année de l\'inscription_Année_N+1']
del ca2015['Année de l\'inscription_Année_N+1']
del ca2016['Année de l\'inscription_Année_N+1']
del ca2017['Année de l\'inscription_Année_N+1']
del ca2018['Année de l\'inscription_Année_N+1']
del ca2019['Année de l\'inscription_Année_N+1']
del ca2020['Année de l\'inscription_Année_N+1']
del ca2021['Année de l\'inscription_Année_N+1']
del ca2022['Année de l\'inscription_Année_N+1']

# %%
data2012=data2012.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2013=data2013.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2014=data2014.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2015=data2015.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2016=data2016.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2017=data2017.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2018=data2018.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2019=data2019.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2020=data2020.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})
data2021=data2021.rename(columns={'Année de l\'inscription_x_Année_N':'Année_N'})

# %%
data2013.columns.tolist()
# Out:
# ['Individu - Code Etudiant',
#  'RNA',
#  'Année_N',
#  'Niveau_Année_N',
#  "Type d'étape_Année_N",
#  'Diplôme SISE intitulé 1 (lib.)_Année_N',
#  'IAE - Etape (lib.)_Année_N',
#  'Individu - Sexe_Année_N',
#  'Nationalité (code)_Année_N',
#  'Nationalité (lib.)_Année_N',
#  'Nationalité - continent_Année_N',
#  'Age au bac_Année_N',
#  'Bac ou équivalence (code)_Année_N',
#  'Groupe de bac_Année_N',
#  'Série du bac_Année_N',
#  'Spécialité 1 du bac NBGE_Année_N',
#  'Bac - Mention (lib.)_Année_N',
#  'Situation année précédente (lib.)_Année_N',
#  'Diplôme SISE (type)_Année_N',
#  'Discipline SISE (code)_Année_N',
#  'Discipline SISE (lib.)_Année_N',
#  'Secteur disciplinaire SISE (code)_Année_N',
#  'Secteur disciplinaire SISE (lib.)_Année_N',
#  'Niveau dans le diplôme (calc)_Année_N',
#  'PCS - parent (code)_Année_N',
#  'PCS - parent (lib.)_Année_N',
#  "Régime d'inscription (code)_Année_N",
#  "Régime d'inscription (lib.)_Année_N",
#  'Boursier (O/N)_Année_N',
# ...

# %%
df2012_2013=pd.merge(data2012,ca2013,on="Individu - Code Etudiant")
df2013_2014=pd.merge(data2013,ca2014,on="Individu - Code Etudiant")
df2014_2015=pd.merge(data2014,ca2015,on="Individu - Code Etudiant")
df2015_2016=pd.merge(data2015,ca2016,on="Individu - Code Etudiant")
df2016_2017=pd.merge(data2016,ca2017,on="Individu - Code Etudiant")
df2017_2018=pd.merge(data2017,ca2018,on="Individu - Code Etudiant")
df2018_2019=pd.merge(data2018,ca2019,on="Individu - Code Etudiant")
df2019_2020=pd.merge(data2019,ca2020,on="Individu - Code Etudiant")
df2020_2021=pd.merge(data2020,ca2021,on="Individu - Code Etudiant")
df2021_2022=pd.merge(data2021,ca2022,on="Individu - Code Etudiant")

# %%
data=pd.concat([df2012_2013,df2013_2014,df2014_2015,df2015_2016,df2016_2017,df2017_2018,df2018_2019,df2020_2021,df2021_2022])
data = data.reset_index(drop=True)

# %%
data.shape
# Out:
# (44740, 91)

# %%
variable_types = data.dtypes.value_counts()
plt.figure(figsize=(8, 6))
variable_types.plot(kind='bar', color='skyblue')
plt.title('Histogramme des Types de Variables')
plt.xlabel('Type de Variable')
plt.ylabel('Nombre de Variables')
plt.xticks(rotation=0)
plt.show()

# %%
file='data.xlsx'
data.to_excel(file)
print("Success")
# Out:
# Success

# %%
del data['Individu - Sexe_Année_N+1']
del data['Nationalité (code)_Année_N+1']
del data['Nationalité (lib.)_Année_N+1']
del data['Nationalité - continent_Année_N+1']
del data['Age au bac_Année_N+1']
del data['Bac ou équivalence (code)_Année_N+1']
del data['Groupe de bac_Année_N+1']
del data['Série du bac_Année_N+1']
del data['Spécialité 1 du bac NBGE_Année_N+1']
del data['Bac - Mention (lib.)_Année_N+1']
del data['Etudiant oui ou oui-si_Année_N+1']
del data['Année 1ère inscript. dans l\'étab._Année_N+1']
del data['Année de dernière inscription_Année_N+1']
del data['Bac - Etab. préparation (code)_Année_N+1']
del data['Code commune Lycée_Année_N+1']
del data['IPS du lycée_Année_N+1']

# %%
H=data[~data['Spécialité 1 du bac NBGE_Année_N'].isna()]
H.shape
# Out:
# (955, 75)

# %%
H['Bac ou équivalence (code)_Année_N'].unique()
# Out:
# array(['NBGE'], dtype=object)

# %% [markdown]
# Seuls les étudiants ayant comme "Bac ou équivalence (code)_Année_N"  NBGE n'ont pas de valeurs manquantes au niveau de la variable "Spécialité 1 du bac NBGE_Année_N". Nous allons donc fusionner ces deux variables

# %%
for i in range(len(data)):
  if data['Bac ou équivalence (code)_Année_N'][i]=="NBGE":
    data['Bac ou équivalence (code)_Année_N'][i]=data['Spécialité 1 du bac NBGE_Année_N'][i]
# Out:
# <ipython-input-35-65ed6a0b0bf7>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Bac ou équivalence (code)_Année_N'][i]=data['Spécialité 1 du bac NBGE_Année_N'][i]

# %%
del data['Spécialité 1 du bac NBGE_Année_N']

# %%
data.shape
# Out:
# (44740, 74)

# %%
data.columns.tolist()
# Out:
# ['Individu - Code Etudiant',
#  'RNA',
#  'Année_N',
#  'Niveau_Année_N',
#  "Type d'étape_Année_N",
#  'Diplôme SISE intitulé 1 (lib.)_Année_N',
#  'IAE - Etape (lib.)_Année_N',
#  'Individu - Sexe_Année_N',
#  'Nationalité (code)_Année_N',
#  'Nationalité (lib.)_Année_N',
#  'Nationalité - continent_Année_N',
#  'Age au bac_Année_N',
#  'Bac ou équivalence (code)_Année_N',
#  'Groupe de bac_Année_N',
#  'Série du bac_Année_N',
#  'Bac - Mention (lib.)_Année_N',
#  'Situation année précédente (lib.)_Année_N',
#  'Diplôme SISE (type)_Année_N',
#  'Discipline SISE (code)_Année_N',
#  'Discipline SISE (lib.)_Année_N',
#  'Secteur disciplinaire SISE (code)_Année_N',
#  'Secteur disciplinaire SISE (lib.)_Année_N',
#  'Niveau dans le diplôme (calc)_Année_N',
#  'PCS - parent (code)_Année_N',
#  'PCS - parent (lib.)_Année_N',
#  "Régime d'inscription (code)_Année_N",
#  "Régime d'inscription (lib.)_Année_N",
#  'Boursier (O/N)_Année_N',
#  'Composante_Année_N',
#  'Cursus LMD_Année_N',
# ...

# %%
data.describe()
# Out:
#        Individu - Code Etudiant       Année_N  Nationalité (code)_Année_N  \
# count              4.474000e+04  44740.000000                44740.000000
# mean               2.020629e+07   2016.182834                  135.755364
# std                1.364628e+06      2.788155                   85.115147
# min                2.002983e+06   2012.000000                  100.000000
# 25%                2.013299e+07   2014.000000                  100.000000
# 50%                2.015521e+07   2016.000000                  100.000000
# 75%                2.018058e+07   2018.000000                  100.000000
# max                9.910335e+07   2021.000000                  501.000000
#
#        Age au bac_Année_N  Discipline SISE (code)_Année_N  \
# count        44565.000000                    44660.000000
# mean            18.465769                        7.184035
# std              1.075102                        5.650768
# min             11.000000                        1.000000
# ...

# %%
donnee=data[['Année_N','Individu - Code Etudiant','Individu - Sexe_Année_N',
 'Nationalité (code)_Année_N',
 'Nationalité (lib.)_Année_N',
 'Nationalité - continent_Année_N',
 'Age au bac_Année_N',
 'Bac ou équivalence (code)_Année_N',
 'Groupe de bac_Année_N',
 'Série du bac_Année_N',
 'Bac - Mention (lib.)_Année_N','Bac - Etab. préparation (code)_Année_N',
 'Code commune Lycée_Année_N',
 'IPS du lycée_Année_N','Etudiant oui ou oui-si_Année_N','PCS - parent (code)_Année_N',
 'PCS - parent (lib.)_Année_N', 'PCS - autre parent (code)_Année_N',
 'Profession du parent 2_Année_N', 'Adresse fixe - Commune (code)_Année_N','nom_de_la_commune_Année_N', 'Distance_en_km_Année_N', "Année 1ère inscript. dans l'étab._Année_N",
 'Année de dernière inscription_Année_N', 'Situation année précédente (lib.)_Année_N', 'Diplôme Evry ou Saclay_Année_N','Niveau_Année_N',
 "Type d'étape_Année_N", 'IAE - Etape (lib.)_Année_N', 'IAE - Etape (code)_Année_N','Diplôme SISE (type)_Année_N',
 'Diplôme SISE intitulé 1 (lib.)_Année_N','Discipline SISE (code)_Année_N',
 'Discipline SISE (lib.)_Année_N',
 'Secteur disciplinaire SISE (code)_Année_N',
 'Secteur disciplinaire SISE (lib.)_Année_N','Composante_Année_N',
 'Cursus LMD_Année_N','Niveau dans le diplôme (calc)_Année_N',"Régime d'inscription (code)_Année_N",
 "Régime d'inscription (lib.)_Année_N",
 'Boursier (O/N)_Année_N', 'Note Session 1_Année_N',
 'Résultat Session 1_Année_N',
 'Note Session 2_Année_N',
 'Résultat Session 2_Année_N', 'Nombre d’admis VET_Année_N', 'PCS - parent (code)_Année_N+1', 'PCS - parent (lib.)_Année_N+1','PCS - autre parent (code)_Année_N+1', 'Profession du parent 2_Année_N+1','Adresse fixe - Commune (code)_Année_N+1','nom_de_la_commune_Année_N+1', 'Distance_en_km_Année_N+1',
  'Situation année précédente (lib.)_Année_N+1', 'Diplôme Evry ou Saclay_Année_N+1','Niveau_Année_N+1',
 "Type d'étape_Année_N+1", 'IAE - Etape (lib.)_Année_N+1', 'IAE - Etape (code)_Année_N+1','Diplôme SISE (type)_Année_N+1',
 'Diplôme SISE intitulé 1 (lib.)_Année_N+1','Discipline SISE (code)_Année_N+1',
 'Discipline SISE (lib.)_Année_N+1',
 'Secteur disciplinaire SISE (code)_Année_N+1',
 'Secteur disciplinaire SISE (lib.)_Année_N+1','Composante_Année_N+1',
 'Cursus LMD_Année_N+1','Niveau dans le diplôme (calc)_Année_N+1',"Régime d'inscription (code)_Année_N+1",
 "Régime d'inscription (lib.)_Année_N+1",
 'Boursier (O/N)_Année_N+1','RNA']]

# %%
columns_data = set(data.columns)
columns_donnee = set(donnee.columns)
columns_non_common = columns_data.symmetric_difference(columns_donnee)
print(columns_non_common)
# Out:
# {'Nombre d’admis VET_Année_N+1'}

# %%
donnee.shape
# Out:
# (44740, 73)

# %%
file1='donnée.xlsx'
donnee.to_excel(file1)
print("Success")
# Out:
# Success

# %%
donnee.describe()
# Out:
#             Année_N  Individu - Code Etudiant  Nationalité (code)_Année_N  \
# count  44740.000000              4.474000e+04                44740.000000
# mean    2016.182834              2.020629e+07                  135.755364
# std        2.788155              1.364628e+06                   85.115147
# min     2012.000000              2.002983e+06                  100.000000
# 25%     2014.000000              2.013299e+07                  100.000000
# 50%     2016.000000              2.015521e+07                  100.000000
# 75%     2018.000000              2.018058e+07                  100.000000
# max     2021.000000              9.910335e+07                  501.000000
#
#        Age au bac_Année_N  IPS du lycée_Année_N  PCS - parent (code)_Année_N  \
# count        44565.000000          34760.000000                 44740.000000
# mean            18.465769             40.185995                    54.747765
# ...

# %%
variables_manquantes = donnee.columns[donnee.isnull().any()]
print(variables_manquantes)
# Out:
# Index(['Age au bac_Année_N', 'Bac - Mention (lib.)_Année_N',
#        'Bac - Etab. préparation (code)_Année_N', 'Code commune Lycée_Année_N',
#        'IPS du lycée_Année_N', 'PCS - autre parent (code)_Année_N',
#        'Profession du parent 2_Année_N',
#        'Adresse fixe - Commune (code)_Année_N', 'nom_de_la_commune_Année_N',
#        'Distance_en_km_Année_N', 'Année de dernière inscription_Année_N',
#        'Niveau_Année_N', 'Diplôme SISE (type)_Année_N',
#        'Diplôme SISE intitulé 1 (lib.)_Année_N',
#        'Discipline SISE (code)_Année_N', 'Discipline SISE (lib.)_Année_N',
#        'Secteur disciplinaire SISE (code)_Année_N',
#        'Secteur disciplinaire SISE (lib.)_Année_N', 'Cursus LMD_Année_N',
#        'Note Session 1_Année_N', 'Résultat Session 1_Année_N',
#        'Note Session 2_Année_N', 'Résultat Session 2_Année_N',
#        'PCS - autre parent (code)_Année_N+1',
#        'Profession du parent 2_Année_N+1',
# ...

# %%
result = donnee.isna().sum().to_string(max_rows=None)

# Affichage des variables avec le nombre de valeurs manquantes par variable
print(result)
# Out:
# Année_N                                            0
# Individu - Code Etudiant                           0
# Individu - Sexe_Année_N                            0
# Nationalité (code)_Année_N                         0
# Nationalité (lib.)_Année_N                         0
# Nationalité - continent_Année_N                    0
# Age au bac_Année_N                               175
# Bac ou équivalence (code)_Année_N                  0
# Groupe de bac_Année_N                              0
# Série du bac_Année_N                               0
# Bac - Mention (lib.)_Année_N                    2511
# Bac - Etab. préparation (code)_Année_N          7522
# Code commune Lycée_Année_N                      9980
# IPS du lycée_Année_N                            9980
# Etudiant oui ou oui-si_Année_N                     0
# PCS - parent (code)_Année_N                        0
# PCS - parent (lib.)_Année_N                        0
# PCS - autre parent (code)_Année_N                  1
# ...

# %%
cara=donnee
cara.shape
# Out:
# (44740, 73)

# %%
cara=donnee
for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='61025':
    cara['nom_de_la_commune_Année_N'][i]="La Baroche-sous-Lucé"
    cara['Distance_en_km_Année_N'][i]=300.8

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='91182':
    cara['nom_de_la_commune_Année_N'][i]="Courcouronnes"
    cara['Distance_en_km_Année_N'][i]=4.0

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='41270':
    cara['nom_de_la_commune_Année_N'][i]="Verdes"
    cara['Distance_en_km_Année_N'][i]=131.5

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='45106':
    cara['nom_de_la_commune_Année_N'][i]="Coudray"
    cara['Distance_en_km_Année_N'][i]=222

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='49016':
    cara['nom_de_la_commune_Année_N'][i]="Bagneux"
    cara['Distance_en_km_Année_N'][i]=29

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='59510':
    cara['nom_de_la_commune_Année_N'][i]="Rosendael"
    cara['Distance_en_km_Année_N'][i]=304.7

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='40901':
    cara['nom_de_la_commune_Année_N'][i]="Hossegor"
    cara['Distance_en_km_Année_N'][i]=749.9

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77491':
    cara['nom_de_la_commune_Année_N'][i]="Veneux-les-Sablons"
    cara['Distance_en_km_Année_N'][i]=53

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77166':
    cara['nom_de_la_commune_Année_N'][i]="Ecuelles"
    cara['Distance_en_km_Année_N'][i]=58.8

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77900':
    cara['nom_de_la_commune_Année_N'][i]="Chelles"
    cara['Distance_en_km_Année_N'][i]=128.8

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='97471':
    cara['nom_de_la_commune_Année_N'][i]="Saint-Denis-La-Reunion"
    cara['Distance_en_km_Année_N'][i]=9622

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77346':
    cara['nom_de_la_commune_Année_N'][i]="Ormeaux"
    cara['Distance_en_km_Année_N'][i]=54

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77910':
    cara['nom_de_la_commune_Année_N'][i]="Chambry"
    cara['Distance_en_km_Année_N'][i]=182.7

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='79264':
    cara['nom_de_la_commune_Année_N'][i]=" Parthenay"
    cara['Distance_en_km_Année_N'][i]=370.7

for i in range(len(cara)):
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='91222':
    cara['nom_de_la_commune_Année_N'][i]="Bretigny-sur-Orge"
    cara['Distance_en_km_Année_N'][i]=14.8
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='28131':
    cara['nom_de_la_commune_Année_N'][i]="Chartres"
    cara['Distance_en_km_Année_N'][i]=41
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='91911':
    cara['nom_de_la_commune_Année_N'][i]="Courcouronnes"
    cara['Distance_en_km_Année_N'][i]=4
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='91912':
    cara['nom_de_la_commune_Année_N'][i]="Evry Courcouronnes"
    cara['Distance_en_km_Année_N'][i]=0
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='92904':
    cara['nom_de_la_commune_Année_N'][i]="Puteaux"
    cara['Distance_en_km_Année_N'][i]=44
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='97489':
    cara['nom_de_la_commune_Année_N'][i]="Saint Pierre La Reunion"
    cara['Distance_en_km_Année_N'][i]=9800
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='59460':
    cara['nom_de_la_commune_Année_N'][i]="Jeumont"
    cara['Distance_en_km_Année_N'][i]=260
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='49289':
    cara['nom_de_la_commune_Année_N'][i]="Angers"
    cara['Distance_en_km_Année_N'][i]=286.6
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='62919':
    cara['nom_de_la_commune_Année_N'][i]="Calais"
    cara['Distance_en_km_Année_N'][i]=265
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='27225':
    cara['nom_de_la_commune_Année_N'][i]="Evreux"
    cara['Distance_en_km_Année_N'][i]=104
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='74011':
    cara['nom_de_la_commune_Année_N'][i]="Annecy"
    cara['Distance_en_km_Année_N'][i]=412
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='85224':
    cara['nom_de_la_commune_Année_N'][i]="Roche-sur-Yon"
    cara['Distance_en_km_Année_N'][i]=380
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='02077':
    cara['nom_de_la_commune_Année_N'][i]="Saint Quentin"
    cara['Distance_en_km_Année_N'][i]=150
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='49363':
    cara['nom_de_la_commune_Année_N'][i]="Angers"
    cara['Distance_en_km_Année_N'][i]=286.6
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='50631':
    cara['nom_de_la_commune_Année_N'][i]="Avranches"
    cara['Distance_en_km_Année_N'][i]=365.4
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='61496':
    cara['nom_de_la_commune_Année_N'][i]="Alencon"
    cara['Distance_en_km_Année_N'][i]=240
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77064':
    cara['nom_de_la_commune_Année_N'][i]="Chelles"
    cara['Distance_en_km_Année_N'][i]=128.8
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='85107':
    cara['nom_de_la_commune_Année_N'][i]="Roche-sur-Yon"
    cara['Distance_en_km_Année_N'][i]=380
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='59540':
    cara['nom_de_la_commune_Année_N'][i]="Lille"
    cara['Distance_en_km_Année_N'][i]=251.7
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='45236':
    cara['nom_de_la_commune_Année_N'][i]="Montargis"
    cara['Distance_en_km_Année_N'][i]=90
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='49349':
    cara['nom_de_la_commune_Année_N'][i]="Saumur"
    cara['Distance_en_km_Année_N'][i]=311.9
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='45192':
    cara['nom_de_la_commune_Année_N'][i]="Orleans"
    cara['Distance_en_km_Année_N'][i]=123.1
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='50640':
    cara['nom_de_la_commune_Année_N'][i]="Saint-Hilaire-du-Harcouët"
    cara['Distance_en_km_Année_N'][i]=330
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='52296':
    cara['nom_de_la_commune_Année_N'][i]="Chaumont"
    cara['Distance_en_km_Année_N'][i]=71.7
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='89026':
    cara['nom_de_la_commune_Année_N'][i]="Auxerre"
    cara['Distance_en_km_Année_N'][i]=144.6
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='67439':
    cara['nom_de_la_commune_Année_N'][i]="Strasbourg"
    cara['Distance_en_km_Année_N'][i]=507
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='35313':
    cara['nom_de_la_commune_Année_N'][i]="Rennes"
    cara['Distance_en_km_Année_N'][i]=32.5
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='67390':
    cara['nom_de_la_commune_Année_N'][i]="Marckolsheim"
    cara['Distance_en_km_Année_N'][i]=505.7
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='38021':
    cara['nom_de_la_commune_Année_N'][i]="Grenoble"
    cara['Distance_en_km_Année_N'][i]=551
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='14265':
    cara['nom_de_la_commune_Année_N'][i]="Caen"
    cara['Distance_en_km_Année_N'][i]=268.2
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='45007':
    cara['nom_de_la_commune_Année_N'][i]="Amilly"
    cara['Distance_en_km_Année_N'][i]=92.4
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77399':
    cara['nom_de_la_commune_Année_N'][i]="Savigny-le-temple"
    cara['Distance_en_km_Année_N'][i]=15.3
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='78524':
    cara['nom_de_la_commune_Année_N'][i]="Limay"
    cara['Distance_en_km_Année_N'][i]=85.8
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='74270':
    cara['nom_de_la_commune_Année_N'][i]="Thones"
    cara['Distance_en_km_Année_N'][i]=550.5
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77105':
    cara['nom_de_la_commune_Année_N'][i]="Meaux"
    cara['Distance_en_km_Année_N'][i]=70.7
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77181':
    cara['nom_de_la_commune_Année_N'][i]="Annemasse"
    cara['Distance_en_km_Année_N'][i]=519.4
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='27642':
    cara['nom_de_la_commune_Année_N'][i]="Evreux"
    cara['Distance_en_km_Année_N'][i]=126.3
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='72117':
    cara['nom_de_la_commune_Année_N'][i]="Mans"
    cara['Distance_en_km_Année_N'][i]=190
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77017':
    cara['nom_de_la_commune_Année_N'][i]="Brie-Comte-Robert"
    cara['Distance_en_km_Année_N'][i]=22.1
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='14376':
    cara['nom_de_la_commune_Année_N'][i]="Lisieux"
    cara['Distance_en_km_Année_N'][i]=235
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='49149':
    cara['nom_de_la_commune_Année_N'][i]="Gennes"
    cara['Distance_en_km_Année_N'][i]=296
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='77149':
    cara['nom_de_la_commune_Année_N'][i]="Cucharmoy"
    cara['Distance_en_km_Année_N'][i]=65.6
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='27676':
    cara['nom_de_la_commune_Année_N'][i]="Trois Lacs"
    cara['Distance_en_km_Année_N'][i]=105
  if cara['Adresse fixe - Commune (code)_Année_N'][i]=='85217':
    cara['nom_de_la_commune_Année_N'][i]="Saint-Georges-de-Montaigu"
    cara['Distance_en_km_Année_N'][i]=388
# Out:
# <ipython-input-48-c6bb97fe696a>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cara['nom_de_la_commune_Année_N'][i]="Courcouronnes"
# <ipython-input-48-c6bb97fe696a>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cara['Distance_en_km_Année_N'][i]=4.0
# <ipython-input-48-c6bb97fe696a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cara['nom_de_la_commune_Année_N'][i]="Coudray"
# ...

# %%
file2='donnees.xlsx'
cara.to_excel(file2)
print("Success")
# Out:
# Success
